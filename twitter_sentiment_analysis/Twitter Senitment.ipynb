# %% [markdown]
# # Twitter Sentiment Analysis in Bahasa Indonesia

# %% [markdown]
# This notebook allow you to run the codes need to do Twitter Senitment Analysis in Bahasa Indonesia. Do note there are cells (it will be pointed out in the comments) you do not need to run the analysises.

# %% [markdown]
# The libraries you need are as follows:
#
# - Python 3.8.12
# - snscrape
# - transformers
# - plotly
# - matplotlib
# - wordcloud
# - PIL

# %%
import translators as ts
from os import path
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
import pandas as pd
from transformers import pipeline
import plotly.express as px

ts._google.language_map
# Out:
# Using Singapore server backend.

# %% [markdown]
# This is the scapper portion of the code. Note that the geolocation is used, with indonesia as the language and date range entered.

# %%
import snscrape.modules.twitter as sntwitter

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('geocode:1.2494,103.8303,2km lang:id since:2019-01-01 until:2020-01-01').get_items()):
    if i>5000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# sample search string
# sentosa (#sentosa) lang:id since:2022-01-01 until:2022-03-31'
# https://github.com/igorbrigadir/twitter-advanced-search
# https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/geo#place
# with the tweet id you can punch it into a browser to view the tweet post twitter.com/anyuser/status/{tweet ID}

# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %% [markdown]
# Time zone is removed in the cell below as part of the code is unable to deal with time zone.

# %%
removed_tzone=tweets_df2
# remove time zonne as excel cannot handle time zone
removed_tzone['Datetime'] = removed_tzone['Datetime'].dt.tz_localize(None)
tweetid= removed_tzone['Tweet Id']

removed_tzone
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 ↔ Welcome 2020 💕\n.\nSemoga kita semu...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                          @susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liat-liat peluang mana tahu ada lokasi bi...     Zulkifli_H
# 1052  Big Merlion.\n#merlion \n#sentosaisland \n#sin...  AKKEY52147106
# 1053  🤘🤙🏽  🇸🇬  #singapore  01.01.19 ph zlateshka 😉🤙🏽...     Lex_Kors1n
# 1054  Mimpiku besar \ndan aku harap aku bisa mewujud...        rosiFJP
#
# [1055 rows x 4 columns]

# %% [markdown]
# Run the cell below if you want to save the file to excel. Note that 2 files are generated. The main excel contains all the extracted tweets and the second file is the ID of the tweet message. Due to the tweet ID being too long. it has be to saved separately

# %%
removed_tzone.to_excel('tweets.xlsx', sheet_name='sheet1', index=False)
# saving results to excel as emojis are unable to be saved in csv form
tweetid.to_csv('tweetsID.csv', index=False)
# due to the tweet ID being too long. it has be to saved separately

# %%
# code for reading excel
removed_tzone=pd.read_excel('geo location 2019 tweets wo emoji translated.xlsx')  

removed_tzone

# %%
text_col=removed_tzone
text_col
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 ↔ Welcome 2020 💕\n.\nSemoga kita semu...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                          @susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liat-liat peluang mana tahu ada lokasi bi...     Zulkifli_H
# 1052  Big Merlion.\n#merlion \n#sentosaisland \n#sin...  AKKEY52147106
# 1053  🤘🤙🏽  🇸🇬  #singapore  01.01.19 ph zlateshka 😉🤙🏽...     Lex_Kors1n
# 1054  Mimpiku besar \ndan aku harap aku bisa mewujud...        rosiFJP
#
# [1055 rows x 4 columns]

# %% [markdown]
# A new column is for the translation of the tweets to English for reference. Note that this might take sometime depending on number of rows as it uses Google translate API to translate the tweets. (1000 rows takes about 22 to 25 minutes)

# %%
text_col['english_text'] = text_col['Text'].apply(lambda x: ts.google(x, from_language='id', to_language='en'))

text_col
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username  \
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 ↔ Welcome 2020 💕\n.\nSemoga kita semu...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                          @susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liat-liat peluang mana tahu ada lokasi bi...     Zulkifli_H
# 1052  Big Merlion.\n#merlion \n#sentosaisland \n#sin...  AKKEY52147106
# 1053  🤘🤙🏽  🇸🇬  #singapore  01.01.19 ph zlateshka 😉🤙🏽...     Lex_Kors1n
# 1054  Mimpiku besar \ndan aku harap aku bisa mewujud...        rosiFJP
#
#                                            english_text
# 0     Me and my friend but there is a sense of sayin...
# 1     Me and my friends PAUDQ wish you a Happy New Y...
# 2     Me and my friend Genk Motorq wish you a Happy ...
# 3     Thank you for being the closing of my beautifu...
# 4     BYE 2019 ↔ WELCOME 2020 💕 \n . \n Hopefully we...
# ...                                                 ...
# 1050                   @susipudjiastuti greetings ma'am
# 1051  Try to look at the opportunity which knows the...
# 1052  Big Merlion. \n #merlion \n #Sentosaisland \n ...
# 1053  🤘🤙🏽 🇸🇬 #Singapore 01.01.19 PH ZLATESHKA 😉🤙🏽 @ ...
# 1054  My dream is big \n And I hope I can make it ha...
#
# [1055 rows x 5 columns]

# %% [markdown]
# Here the emojis and emoticon are converted into English.

# %%
import demoji

n=0
for v in text_col["Text"]:
    raw_tweet = str(v)
    tweet_removed_emoji = demoji.replace_with_desc(raw_tweet)
    text_col.loc[n,"Text"] = tweet_removed_emoji

    n+=1

text_col["Text"] = text_col["Text"].str.replace('[^\w\s]','',regex=True)
text_col["Text"] = text_col["Text"].str.replace('\n',' ',regex=True)

text_col
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username  \
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 leftright arrow Welcome 2020 two hear...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                           susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liatliat peluang mana tahu ada lokasi bis...     Zulkifli_H
# 1052  Big Merlion merlion  sentosaisland  singapore ...  AKKEY52147106
# 1053  sign of the hornscall me hand medium skin tone...     Lex_Kors1n
# 1054  Mimpiku besar  dan aku harap aku bisa mewujudk...        rosiFJP
#
#                                            english_text
# 0     Me and my friend but there is a sense of sayin...
# 1     Me and my friends PAUDQ wish you a Happy New Y...
# 2     Me and my friend Genk Motorq wish you a Happy ...
# 3     Thank you for being the closing of my beautifu...
# 4     BYE 2019 ↔ WELCOME 2020 💕 \n . \n Hopefully we...
# ...                                                 ...
# 1050                   @susipudjiastuti greetings ma'am
# 1051  Try to look at the opportunity which knows the...
# 1052  Big Merlion. \n #merlion \n #Sentosaisland \n ...
# 1053  🤘🤙🏽 🇸🇬 #Singapore 01.01.19 PH ZLATESHKA 😉🤙🏽 @ ...
# 1054  My dream is big \n And I hope I can make it ha...
#
# [1055 rows x 5 columns]

# %% [markdown]
# The english words converted from the emojis and emoticons are converted back into Bahasa Indonesia. (1000 rows takes about 22 to 25 minutes)

# %%
# the language can be changed depending on what you require
text_col['FullText'] = text_col['Text'].apply(lambda x: ts.google(x, from_language='en', to_language='id'))

text_col
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username  \
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 leftright arrow Welcome 2020 two hear...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                           susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liatliat peluang mana tahu ada lokasi bis...     Zulkifli_H
# 1052  Big Merlion merlion  sentosaisland  singapore ...  AKKEY52147106
# 1053  sign of the hornscall me hand medium skin tone...     Lex_Kors1n
# 1054  Mimpiku besar  dan aku harap aku bisa mewujudk...        rosiFJP
#
#                                            english_text  \
# 0     Me and my friend but there is a sense of sayin...
# 1     Me and my friends PAUDQ wish you a Happy New Y...
# 2     Me and my friend Genk Motorq wish you a Happy ...
# 3     Thank you for being the closing of my beautifu...
# 4     BYE 2019 ↔ WELCOME 2020 💕 \n . \n Hopefully we...
# ...                                                 ...
# 1050                   @susipudjiastuti greetings ma'am
# 1051  Try to look at the opportunity which knows the...
# 1052  Big Merlion. \n #merlion \n #Sentosaisland \n ...
# 1053  🤘🤙🏽 🇸🇬 #Singapore 01.01.19 PH ZLATESHKA 😉🤙🏽 @ ...
# 1054  My dream is big \n And I hope I can make it ha...
#
#                                                FullText
# 0     AKU dan TEMEN TAPI ADA Rasa Mengucapkan Selama...
# 1     AKU dan TEMEN2 PAUDQ MENGUCAPKAN SELAMAT TAHUN...
# 2     AKU dan TEMEN GENK MOTORQ MENGUCAPKAN SELAMAT ...
# 3     Terimakasih sudah menjadi penutup 2019ku Yang ...
# 4     Bye 2019 Leftright Panah Selamat Datang 2020 T...
# ...                                                 ...
# 1050                          Susi pudjiastuti dalam bi
# 1051  COBA LIATLIAT PELUANG MANA TAHU ADA LOKASI BIS...
# 1052  Big Merlion Merlion Sentosa Island Singapore 場...
# 1053  Tanda Hornscall Me Tangan Medium Kulit Bendera...
# 1054  Mimpiku Besar Dan Aku Harak Aku Bisa Mewujudka...
#
# [1055 rows x 6 columns]

# %% [markdown]
# Run the code below if you want to save the dataframe.

# %%
tweetid= removed_tzone['Tweet Id']
# due to the tweet ID being too long. it has be to saved separately
removed_tzone.to_excel('tweets wo emoji.xlsx', sheet_name='sheet1', index=False)
# saving results to excel as emojis are unable to be saved in csv form

# %% [markdown]
# The next few codes below are setting up for word cloud display. This will be used to identify keywords used in the tweets and assists to check if there are iirelevant tweets and how much of them are irrelevant.

# %%
t_df = pd.DataFrame(text_col, columns = ['english_text'])

t_df
# Out:
#                                            english_text
# 0     Me and my friend but there is a sense of sayin...
# 1     Me and my friends PAUDQ wish you a Happy New Y...
# 2     Me and my friend Genk Motorq wish you a Happy ...
# 3     Thank you for being the closing of my beautifu...
# 4     BYE 2019 ↔ WELCOME 2020 💕 \n . \n Hopefully we...
# ...                                                 ...
# 1050                   @susipudjiastuti greetings ma'am
# 1051  Try to look at the opportunity which knows the...
# 1052  Big Merlion. \n #merlion \n #Sentosaisland \n ...
# 1053  🤘🤙🏽 🇸🇬 #Singapore 01.01.19 PH ZLATESHKA 😉🤙🏽 @ ...
# 1054  My dream is big \n And I hope I can make it ha...
#
# [1055 rows x 1 columns]

# %%
text = t_df["english_text"].to_string(index=False)
text_raw = text_col["FullText"].to_string(index=False)
print ("There are {} words in the combination of all tweets.".format(len(text)))
print ("There are {} words in the combination of all tweets.".format(len(text_raw)))
# Out:
# There are 53804 words in the combination of all tweets.
# There are 53804 words in the combination of all tweets.

# %% [markdown]
# The first word cloud is completed for the translated column and the second is for the original tweet column

# %%
wordcloud = WordCloud(width=1600, height=800).generate(text)

plt.figure(figsize=[20,10])
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
wordcloud_raw = WordCloud(width=1600, height=800).generate(text_raw)

plt.figure(figsize=[20,10])
plt.imshow(wordcloud_raw,interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
word_count = WordCloud().process_text(text)

word_count
# Out:
# {'friend': 11,
#  'sense': 2,
#  'saying': 1,
#  'PAUDQ': 1,
#  'wish': 2,
#  'happy': 22,
#  'new': 9,
#  'ye': 12,
#  'Genk': 1,
#  'Motorq': 1,
#  'n': 114,
#  'Thank': 8,
#  'closing': 2,
#  'beautiful': 5,
#  'BYE': 1,
#  'Welcome': 4,
#  'Hopefully': 9,
#  'Rain': 2,
#  'cover': 2,
#  'year': 12,
#  'Earth': 1,
#  'bathed': 1,
#  'fairy': 1,
#  's': 22,
#  'DTG': 2,
#  'Lun': 1,
#  'Caption': 1,
#  'Love': 5,
#  'kajolatun': 1,
#  'less': 3,
#  'height': 2,
#  'yer': 1,
#  'tomcruise': 1,
#  'Ma': 7,
#  'HappyNewyear2020': 1,
#  'Singapore': 42,
#  'Sakura': 1,
#  'https': 3,
#  'indeed': 4,
#  'lesen': 1,
#  'motorbike': 1,
#  'tujercaption': 1,
#  'face': 5,
#  'cristiano': 2,
#  'unable': 2,
#  'serve': 2,
#  'alrea': 1,
#  'queen': 2,
#  'still': 14,
#  'looking': 7,
#  'social': 2,
#  'next': 7,
#  'go': 25,
#  'OKEI': 1,
#  'Genting': 3,
#  'photo': 59,
#  'almost': 3,
#  'similar': 2,
#  'b': 7,
#  'many': 10,
#  'moment': 5,
#  'always': 14,
#  'y': 7,
#  'Assisting': 1,
#  'Sempena': 1,
#  'Birthday': 4,
#  'ABG': 1,
#  'Nazri': 1,
#  'Sat': 1,
#  'cloves': 1,
#  'amp': 6,
#  'Tri': 2,
#  'radenrauf': 1,
#  'visite': 1,
#  'Enjoying': 3,
#  'grateful': 4,
#  'vivocity': 9,
#  'Abracadabra': 1,
#  'Universal': 11,
#  'ball': 3,
#  'jiro': 1,
#  'co': 1,
#  'peuanwrkhq': 1,
#  'crowded': 5,
#  'take': 12,
#  'f': 4,
#  'Busyness': 1,
#  'managed': 1,
#  'conquer': 1,
#  'negative': 1,
#  'Excuseme': 1,
#  'right': 4,
#  'sitting': 2,
#  'rollercoaster': 3,
#  'real': 4,
#  'Shucks': 1,
#  'want': 25,
#  'Padang': 1,
#  'rice': 4,
#  'Bismillah': 2,
#  'Friday': 3,
#  'Barokah': 1,
#  'end': 4,
#  'come': 10,
#  'adorable': 1,
#  'cleaning': 1,
#  'gallery': 1,
#  'find': 2,
#  'w': 8,
#  'Kembara': 1,
#  'long': 16,
#  'time': 38,
#  'soul': 3,
#  'young': 1,
#  'Tamang': 2,
#  'Tambay': 1,
#  'Kahit': 1,
#  'Walang': 1,
#  'Pera': 1,
#  'Kidzania': 2,
#  'bmh2fpb2zv': 1,
#  'Jellyfish': 1,
#  'Sea': 7,
#  'Aquarium': 6,
#  'Anyone': 1,
#  'defines': 1,
#  'knowing': 1,
#  'h': 4,
#  'already': 12,
#  'rising': 1,
#  'thought': 3,
#  'xbawak': 1,
#  'kete': 1,
#  'ju': 1,
#  'makaya': 1,
#  'hahahahahahahaa': 1,
#  'will': 14,
#  'future': 1,
#  'cherylardih': 1,
#  'ok': 4,
#  'Caya': 1,
#  'came': 2,
#  'bring': 5,
#  'child': 5,
#  'Used': 2,
#  'Bawak': 3,
#  'Mikael': 1,
#  'Tempok': 1,
#  'Pulak': 1,
#  'fish': 6,
#  'e': 6,
#  'aquari': 1,
#  'told': 1,
#  'split': 1,
#  'monster': 1,
#  'cookie': 1,
#  'th': 7,
#  'ride': 14,
#  'Finally': 7,
#  'achieved': 2,
#  'yet': 3,
#  'M': 13,
#  'Choosing': 1,
#  'suitable': 1,
#  'tourist': 3,
#  'spot': 4,
#  'Mandatory': 2,
#  'PLAYAL': 1,
#  'SOLAT': 1,
#  'first': 20,
#  'Mosq': 1,
#  '新加坡': 1,
#  'Monung': 1,
#  'xe4xubbhef': 1,
#  'Holiday': 7,
#  'sponsored': 1,
#  'newbalancesg': 1,
#  'turtle': 4,
#  'boa': 2,
#  'really': 9,
#  'temples': 1,
#  'Entrance': 2,
#  'ticket': 1,
#  'USS': 9,
#  'buy': 4,
#  'Kat': 3,
#  'Klook': 1,
#  'guys': 6,
#  'universalstudios': 1,
#  'high': 4,
#  'Non': 4,
#  'banana': 2,
#  'ni': 6,
#  'un': 3,
#  'Ang': 7,
#  'Hirapa': 1,
#  'Libutin': 1,
#  'ng': 10,
#  'sobrang': 2,
#  'lakas': 1,
#  'ulan': 1,
#  'Hello': 1,
#  'Mee': 1,
#  'Pok': 1,
#  'favorite': 3,
#  'Aleks': 1,
#  'ymrnxphqt9': 1,
#  'hijaukantwitter': 1,
#  'Green': 1,
#  'llzunxwjsk': 1,
#  'FAVERET': 1,
#  'CARTOON': 1,
#  'Kecik2': 1,
#  'DLU': 3,
#  'mig': 1,
#  'Wed': 1,
#  'Dec': 1,
#  'HSATRAVELINGSINGAPORE': 1,
#  'HSauniv': 1,
#  'mamimencit': 1,
#  'ciamikboy': 1,
#  'liamgl_': 1,
#  'abcdepiii': 1,
#  'choose': 5,
#  'Summer': 1,
#  'Winter': 1,
#  'Season': 1,
#  'Altho': 1,
#  'two': 2,
#  'piceless': 1,
#  'bucin': 1,
#  'kshjcj49jj': 1,
#  'waiting': 5,
#  '50mins': 1,
#  'Takde': 3,
#  'house': 3,
#  'World': 5,
#  'cruel': 1,
#  'think': 3,
#  'Offering': 3,
#  'clear': 1,
#  'experience': 3,
#  'clearly': 1,
#  'dif': 1,
#  'entered': 2,
#  'shop': 2,
#  'son': 16,
#  'wifi': 1,
#  'know': 8,
#  'Stop': 2,
#  'believe': 3,
#  'Climbed': 1,
#  'Shibuya': 1,
#  'tuk': 4,
#  'cha': 4,
#  'qa2ajuarr8': 1,
#  'Btw': 2,
#  'Malaysian': 1,
#  'people': 11,
#  'Bat': 2,
#  'far': 1,
#  'forgot': 3,
#  'Powerbank': 1,
#  'month': 3,
#  'half': 2,
#  'Coffee': 1,
#  'Bean': 1,
#  'Mosque': 1,
#  'sent': 38,
#  'Singapo': 4,
#  'Shangri': 1,
#  'Sentosa': 32,
#  'curious': 1,
#  'vacation': 9,
#  'cru': 2,
#  'Sing': 5,
#  'usually': 2,
#  'mung': 3,
#  'mlebu': 1,
#  'sun': 4,
#  'lan': 1,
#  'tukune': 1,
#  'nev': 1,
#  "Ma'am": 3,
#  'later': 3,
#  'Excitement': 2,
#  'zybjvo0wqf': 1,
#  'trying': 4,
#  'enjoy': 2,
#  'even': 3,
#  'thinking': 1,
#  'abou': 1,
#  'ACABA': 1,
#  'DE': 2,
#  'PUBLICAR': 1,
#  'UNA': 1,
#  'en': 1,
#  'Catcher': 1,
#  'Indonesia': 4,
#  'ht': 5,
#  'Rainy': 1,
#  'sg': 3,
#  'bbhmlke4jx': 1,
#  'Alhamdulilah': 1,
#  'Ujan': 1,
#  'rccwf2fdzt': 1,
#  'Younger': 1,
#  'sister': 4,
#  'Brother': 2,
#  'Mommy': 2,
#  'Singap': 5,
#  'Last': 4,
#  'night': 11,
#  'met': 2,
#  'Kak': 1,
#  'Lili': 1,
#  'Siregar': 1,
#  'KPK': 1,
#  'RI': 2,
#  'c': 6,
#  'Morally': 1,
#  'tide': 1,
#  'leave': 3,
#  'Singta': 1,
#  'Cove': 3,
#  'Tyzorasu': 1,
#  'human': 3,
#  'self': 2,
#  'faith': 1,
#  'Adikkkkk': 1,
#  'Holiyeaayyy': 1,
#  'hard': 6,
#  'tak': 1,
#  'Wefie': 2,
#  'fits': 1,
#  'port': 2,
#  'xlmediagathering2019': 1,
#  'Working': 1,
#  'Touring': 1,
#  'travel': 3,
#  'feel': 9,
#  'Batam': 5,
#  'car': 3,
#  'Rental': 1,
#  'place': 7,
#  'Now': 7,
#  'need': 4,
#  'Crasek': 1,
#  'carry': 1,
#  'anywhere': 3,
#  'especially': 1,
#  'yo': 5,
#  'better': 4,
#  'regret': 1,
#  'try': 8,
#  'rather': 1,
#  'tha': 1,
#  'instagram': 3,
#  'ins': 1,
#  'vehicle': 1,
#  'must': 7,
#  'tried': 2,
#  'Sen': 1,
#  'Picnic': 4,
#  'insta': 2,
#  'Minister': 1,
#  'said': 4,
#  'Mata': 3,
#  'Najwa': 1,
#  'Obagidaa': 1,
#  'terreeey': 1,
#  'hoho': 1,
#  'see': 6,
#  'Jalan2': 1,
#  'afternoon': 2,
#  'sbk2acwtuc': 1,
#  'Rarely': 1,
#  'going': 6,
#  'viewed': 1,
#  'Twinning': 1,
#  'Jatesahabuhay': 1,
#  'Sofitel': 2,
#  'Figure': 1,
#  'respected': 1,
#  'everyon': 1,
#  'MRT': 2,
#  'near': 3,
#  'zan': 1,
#  'extra': 2,
#  'bag': 2,
#  'Lunch': 5,
#  'vrcjx9877c': 1,
#  'Hansem': 1,
#  'takpe': 1,
#  'style': 1,
#  'center': 3,
#  'attention': 1,
#  'known': 1,
#  'Malaysia': 2,
#  'LGT': 1,
#  'Bank': 1,
#  'D': 6,
#  'Amara': 2,
#  'Sanctuary': 1,
#  'G': 5,
#  'Christmas': 1,
#  'Party': 1,
#  'Bikini': 2,
#  'Bar': 1,
#  'candy': 1,
#  'sweet': 2,
#  'tamarind': 1,
#  'Greetings': 4,
#  'liferecordsmy': 1,
#  'offi': 2,
#  'Today': 5,
#  'share': 1,
#  'pi': 2,
#  'Brick': 1,
#  'Maging': 1,
#  'dwxlueix18': 1,
#  'count': 2,
#  'Thursdays': 1,
#  'e0cwc8hfgn': 1,
#  'one': 14,
#  'cowardly': 1,
#  'riding': 3,
#  'everything': 1,
#  'small': 2,
#  'large': 1,
#  'weekendvibes': 1,
#  'syun': 1,
#  'rpvrgu': 1,
#  'second': 3,
#  'round': 2,
#  'Q': 1,
#  'Yakitori': 2,
#  'Te': 1,
#  'Nayuki': 2,
#  'Telok': 5,
#  'Actually': 2,
#  'successful': 1,
#  'able': 2,
#  'handle': 2,
#  'terokss': 1,
#  'husband': 2,
#  'free': 4,
#  'cellphone': 2,
#  'cool': 3,
#  'edits': 1,
#  'acwlqo6cpy': 1,
#  'Living': 3,
#  'Merlion': 16,
#  'Sento': 9,
#  'droneraceleague': 1,
#  'FPV': 1,
#  'gang': 4,
#  'Taking': 2,
#  'Singapor': 8,
#  'daily': 1,
#  'reporter': 1,
#  'cam': 1,
#  'lot': 6,
#  'gambo': 2,
#  'je': 3,
#  'sin': 5,
#  'queues': 1,
#  'Si': 12,
#  'tempted': 1,
#  'mystery': 1,
#  'unive': 1,
#  'delivered': 1,
#  'Chevy': 1,
#  'Bigblock': 1,
#  'kmbzmrlyf': 1,
#  'Aida': 1,
#  'Vita': 1,
#  'Installs': 1,
#  'Flag': 1,
#  'Mexico': 1,
#  'cruisi': 1,
#  'additional': 1,
#  'energy': 1,
#  'ujnd6z': 1,
#  'word': 4,
#  'motto': 2,
#  '4x': 1,
#  'Learning': 2,
#  'develop': 1,
#  'benchmark': 1,
#  'klh': 1,
#  'Ahm': 1,
#  'Mejo': 1,
#  'Maalon': 1,
#  'Na': 7,
#  'Po': 1,
#  'Contain': 2,
#  'o': 7,
#  'omdirects_': 1,
#  'Please': 2,
#  'doong': 1,
#  'weekendngedit': 1,
#  'wea': 1,
#  'Great': 3,
#  'sir': 3,
#  'ncqkw1fu2e': 1,
#  'Jiran': 1,
#  'Pilgrimage': 1,
#  'Strong': 2,
#  'Zero': 1,
#  'KW': 2,
#  'Super': 1,
#  'weekend': 2,
#  'forget': 7,
#  'gaess': 1,
#  'Nagnyelfie': 1,
#  'Daddy': 2,
#  'One15': 2,
#  'Luxury': 1,
#  'Yachti': 1,
#  'Life': 14,
#  'achieve': 2,
#  'wreck': 1,
#  'shipwreck': 1,
#  'Selfie': 6,
#  'dato': 1,
#  'khai_salleh': 1,
#  'wira': 1,
#  'film': 2,
#  'DJ': 1,
#  'Wale': 1,
#  'Babu': 1,
#  'wr5hw9r44l': 1,
#  'Invited': 2,
#  'meet': 8,
#  'Yuii': 1,
#  'ej99euykna': 1,
#  'thing': 2,
#  'situations': 1,
#  'unt': 1,
#  'Sorry': 3,
#  'Admin': 1,
#  'Services': 1,
#  'Item': 1,
#  'eh': 3,
#  'good': 12,
#  'Solo': 1,
#  'traveling': 2,
#  'Maybe': 2,
#  'tomorrow': 2,
#  'finished': 4,
#  'voya': 1,
#  'Salted': 1,
#  'Caramel': 1,
#  'Brown': 1,
#  'Sugar': 1,
#  'Boba': 1,
#  'Milk': 2,
#  'Fly': 1,
#  'ama': 1,
#  'mamah': 2,
#  'papah': 1,
#  'best': 8,
#  'maulidur': 1,
#  'apostl': 1,
#  'Singa': 4,
#  'id_oriflame': 1,
#  'Nanta': 1,
#  'Wakanda': 1,
#  'Poreber': 1,
#  'iphon': 1,
#  'Monggo': 1,
#  'order': 3,
#  'gt': 3,
#  'feeling': 5,
#  'glowing': 1,
#  'sunbathe': 1,
#  'beac': 1,
#  'Muna': 4,
#  'Bago': 1,
#  'Gibain': 1,
#  'htt': 6,
#  'Kalini': 1,
#  'cino': 1,
#  'tea': 4,
#  'ynqxg0mmt3': 1,
#  'amazing': 2,
#  'dare': 1,
#  'bung': 1,
#  'Step': 2,
#  'public': 2,
#  'library': 2,
#  'seve': 1,
#  'Reach': 1,
#  'ambition': 2,
#  'sky': 2,
#  'trust': 1,
#  'tired': 7,
#  'sl': 1,
#  'Hbd': 1,
#  'syg': 1,
#  'blissful': 1,
#  'ahead': 1,
#  'God': 3,
#  'Alhamdulillah': 9,
#  'Woman': 1,
#  'Race': 2,
#  'Marina': 2,
#  'Bay': 2,
#  'journey': 5,
#  'felt': 2,
#  'sle': 2,
#  'choice': 3,
#  'natural': 2,
#  'Wis': 2,
#  'Kangen': 1,
#  'Karo': 1,
#  'Mendoan': 1,
#  'cdofbg': 1,
#  'Phone': 2,
#  'Giant': 1,
#  'Kjwanders': 1,
#  'day': 14,
#  'Puaih': 1,
#  'Ati': 1,
#  'haunted': 1,
#  'thoug': 1,
#  'Palawab': 1,
#  'Beach': 5,
#  'morning': 8,
#  'bright': 1,
#  'Quite': 2,
#  'comments': 1,
#  'deliciou': 4,
#  'color': 2,
#  'match': 2,
#  'lighting': 1,
#  'spirit': 3,
#  'Walking': 5,
#  'Sunday': 1,
#  'Highlan': 1,
#  'angry': 1,
#  'insult': 1,
#  'family': 3,
#  'attended': 1,
#  'Dinn': 1,
#  'girl': 2,
#  'hysterical': 1,
#  'Monday': 1,
#  'beca': 1,
#  'Jah': 1,
#  'arrival': 1,
#  'Crete': 1,
#  'transportation': 1,
#  'calm': 2,
#  'ufvmk': 1,
#  'Diwali': 1,
#  'short': 2,
#  'qaisarahzahra': 1,
#  'raisham': 1,
#  'Nakakatakot': 1,
#  'Yung': 1,
#  'Haba': 1,
#  'Pila': 1,
#  'Intermezo': 1,
#  'Post': 2,
#  'University': 1,
#  'guildmate': 1,
#  'mistake': 2,
#  'fail': 1,
#  'tinning': 1,
#  'weather': 1,
#  'suppor': 1,
#  'Done': 3,
#  'looted': 1,
#  'Temasek': 1,
#  'clothesline': 1,
#  'huh': 1,
#  'cable': 1,
#  'ca': 1,
#  'Tempt': 1,
#  'gate': 2,
#  'visit': 2,
#  'Tngok': 1,
#  'Swatch': 1,
#  'jap': 1,
#  'vivocitysg': 2,
#  'becomes': 2,
#  'sleepy': 1,
#  '7EF5W9YMXV': 1,
#  'Ngampul': 1,
#  'gaes': 3,
#  'clown': 1,
#  'ghost': 1,
#  'wkwkwkwk': 1,
#  'bhb': 1,
#  'Check': 2,
#  'Tau': 1,
#  'Ngonolo': 1,
#  'Rek': 1,
#  '8b8vvwuluj': 1,
#  'Santosa': 2,
#  'gezfjgihrw': 1,
#  'picture': 5,
#  'jab': 1,
#  'buying': 2,
#  'photographing': 1,
#  'model': 2,
#  'person': 3,
#  'certain': 1,
#  'env': 1,
#  'Look': 10,
#  'PON': 2,
#  'crew': 4,
#  'enough': 2,
#  'smi': 1,
#  'Tggu': 1,
#  'iols': 1,
#  'Lyn': 1,
#  'vomit': 1,
#  'Sunset': 2,
#  'KT': 1,
#  'plok': 1,
#  'fun': 5,
#  'Portrait': 1,
#  'Se': 6,
#  'Wiwiwiwiiii': 1,
#  'Ulti': 1,
#  'Live': 3,
#  'Blanga': 1,
#  'art': 2,
#  'workers': 1,
#  'took': 2,
#  'Outfit': 1,
#  'home': 4,
#  'sak': 2,
#  'left': 2,
#  'dense': 1,
#  'resentful': 2,
#  'someone': 3,
#  'checked': 2,
#  'wherever': 1,
#  'remember': 1,
#  'sooner': 1,
#  'ready': 2,
#  'nagging': 1,
#  'Restaurant': 2,
#  'rest': 3,
#  'guard': 1,
#  'slave': 2,
#  'lol': 2,
#  'every': 6,
#  'player': 2,
#  'respect': 1,
#  'blurry': 1,
#  'Mal': 1,
#  'Gargantuan': 1,
#  'csha2': 1,
#  'Duck': 1,
#  'Ngah': 1,
#  'Sale': 2,
#  'kf96lm': 1,
#  'Seb': 1,
#  'Baek': 1,
#  'Ade': 2,
#  'Meal': 1,
#  'Voucher': 1,
#  'Talisman': 1,
#  'Praying': 2,
#  'key': 1,
#  'success': 3,
#  'involving': 1,
#  'Encourager': 1,
#  'TER': 1,
#  'newbusroutecentosa': 1,
#  'imiah': 1,
#  'May': 4,
#  'Pasok': 1,
#  'Bukas': 2,
#  'Miko': 1,
#  'Supply': 1,
#  'SKUY': 1,
#  '1phyw4etoe': 1,
#  'SK': 1,
#  'Kampung': 1,
#  'pool': 3,
#  'Kuala': 2,
#  'Rompin': 1,
#  'say': 4,
#  'hoax': 1,
#  'yerrr': 1,
#  'fat': 3,
#  'nii': 1,
#  'tuu': 1,
#  'takleh': 1,
#  'duhh': 1,
#  'Sticker': 1,
#  'biadap': 1,
#  'owner': 1,
#  'y7wq5b6rtw': 1,
#  'ACU': 1,
#  'goes': 3,
#  'Suddenly': 1,
#  'Aadmi': 1,
#  'KA': 1,
#  'KHUD': 1,
#  'PE': 1,
#  'BHAROSA': 1,
#  'USKI': 1,
#  'TAQAT': 1,
#  'HOTI': 1,
#  'HAI': 1,
#  'continue': 4,
#  'fygd0psijw': 1,
#  'Marine': 2,
#  'Malay': 2,
#  'Sgd': 1,
#  'galaxy': 1,
#  'fold': 1,
#  'samsung': 1,
#  'store': 1,
#  'Enter': 2,
#  '5Q4VNHVTNQ': 1,
#  'Captainairwolf': 1,
#  'account': 1,
#  'temporarily': 1,
#  'unavai': 1,
#  'typi': 2,
#  'Monkey': 1,
#  'Based': 2,
#  'pamper': 1,
#  'yoursel': 1,
#  'forgotten': 1,
#  'ヅ': 1,
#  'weakening': 1,
#  'heart': 8,
#  'bringing': 1,
#  '15Meedsaja': 1,
#  'eat': 6,
#  'directly': 1,
#  '3x': 1,
#  'hotel': 1,
#  'Guest': 1,
#  'Dip': 1,
#  'guyz': 1,
#  'Kamal': 2,
#  'Job': 1,
#  'crui': 1,
#  'getting': 1,
#  'closer': 1,
#  'Shrek': 1,
#  'Advenger': 1,
#  'TRIPSINGAPORE2019': 1,
#  'Da': 2,
#  'brp': 1,
#  '1st': 1,
#  'st': 1,
#  'became': 1,
#  'captain': 1,
#  'Tuuuu': 1,
#  'Kappucino': 1,
#  'Paik': 1,
#  'bcogd5djoe': 1,
#  'massage': 1,
#  'make': 5,
#  'sure': 1,
#  'Triumphantly': 1,
#  'survive': 1,
#  'eye': 2,
#  'pain': 3,
#  'Petan': 1,
#  'Petenteng': 1,
#  'customs': 1,
#  'clothes': 1,
#  'Bike': 1,
#  '福建': 2,
#  '炒': 2,
#  'apdet': 1,
#  'lonely': 1,
#  'advantages': 1,
#  'liptint': 1,
#  'water': 4,
#  'Bro': 2,
#  'Arnold': 1,
#  'Ciye': 1,
#  'widyasyahranii': 1,
#  'instapic': 1,
#  'throwBack': 3,
#  'Muji': 3,
#  'ggcja3rjew': 1,
#  'September': 1,
#  'umbrella': 1,
#  'yaa': 2,
#  'diligent': 1,
#  'bathing': 1,
#  'interesting': 2,
#  'Merli': 1,
#  'ndjaludn0i': 1,
#  'Koko': 1,
#  'Andy': 1,
#  'likes': 3,
#  'kiss': 1,
#  'Bang': 2,
#  'Johnny': 1,
#  'Dinner': 3,
#  'PPPPPOPOOOOP': 1,
#  'Friedhokkienprawnmee': 4,
#  'dizzy': 1,
#  'head': 1,
#  'gosh': 1,
#  'rgrgx': 1,
#  'TSM': 1,
#  'Cibubur': 1,
#  'Johny': 1,
#  'BNI': 2,
#  'EXEC': 1,
#  'Dir': 1,
#  'Michael': 1,
#  'Ex': 1,
#  'Jln2': 1,
#  'DH': 2,
#  'Jln': 1,
#  'includes': 1,
#  'Rolle': 2,
#  'Drink': 1,
#  'Expresso': 1,
#  'Italian': 1,
#  'retur': 1,
#  'im': 2,
#  'mature': 1,
#  'plus': 1,
#  'brain': 1,
#  'mak': 2,
#  'FULLY': 1,
#  'FUNDED': 1,
#  'awards': 1,
#  'CID': 1,
#  'Woohooooo': 1,
#  'fn8fkunbrg': 1,
#  'thousand': 3,
#  'goodness': 1,
#  'erased': 1,
#  'wit': 1,
#  'lion': 5,
#  'pfttzgna63': 1,
#  'lost': 7,
#  'whe': 2,
#  'miss': 7,
#  'Bogo50': 1,
#  'promo': 1,
#  'Royal': 1,
#  'Caribbea': 1,
#  'Sand': 1,
#  'instagood': 1,
#  'longer': 1,
#  'competing': 1,
#  'sad': 4,
#  'wrote': 1,
#  'poetry': 1,
#  'sadness': 1,
#  'write': 1,
#  'Path': 1,
#  'Taken': 3,
#  'Sundayfunday': 1,
#  'sh': 1,
#  'break': 2,
#  'Asasentosa': 1,
#  'tour': 3,
#  '20km': 1,
#  'play': 5,
#  'hot': 5,
#  'little': 5,
#  'playing': 3,
#  'ny': 1,
#  'Close': 1,
#  'udhungada': 1,
#  'sangu': 1,
#  'Palawan': 2,
#  'gr': 1,
#  'Silososandstation': 1,
#  'starwarssandstation2019': 1,
#  'playmates': 1,
#  'fighting': 3,
#  'Let': 4,
#  'important': 2,
#  'Lil': 1,
#  'Z': 2,
#  'Walk': 4,
#  'period': 1,
#  'turn': 3,
#  'Wanna': 1,
#  'Romantic': 1,
#  'sar': 1,
#  'Haa': 1,
#  'usual': 2,
#  'mcm': 1,
#  'partner': 2,
#  'Plaza': 2,
#  'Hamda': 1,
#  'Osaka': 1,
#  ...}

# %%
word_count_raw = WordCloud().process_text(text_raw)

word_count_raw
# Out:
# {'Aku': 40,
#  'dan': 28,
#  'TEMEN': 2,
#  'Tapi': 18,
#  'Ada': 38,
#  'Rasa': 2,
#  'Selamat': 14,
#  'TEMEN2': 1,
#  'PAUDQ': 1,
#  'tahun': 12,
#  'GENK': 1,
#  'MOTORQ': 1,
#  't': 8,
#  'Terimakasih': 1,
#  'Sudah': 11,
#  'Menjadi': 6,
#  'penutup': 2,
#  '2019ku': 1,
#  'Yang': 56,
#  'Bye': 1,
#  'Leftright': 1,
#  'Panah': 2,
#  'Datang': 6,
#  'Tw': 1,
#  'hujan': 3,
#  'bumi': 2,
#  'Bermandikan': 1,
#  'Peri': 1,
#  'di': 75,
#  'Ki': 2,
#  'seru': 4,
#  'MarkParty': 1,
#  'Popperparty': 2,
#  'Popper': 2,
#  'h': 9,
#  'Tak': 33,
#  'Larat': 1,
#  'Barat': 7,
#  'Caption': 1,
#  'wajah': 33,
#  'Singir': 1,
#  'dengan': 20,
#  'Ker': 2,
#  'lebih': 8,
#  'kurang': 2,
#  'jer': 2,
#  'ketgian': 2,
#  'kita': 15,
#  'yer': 1,
#  'tomcruise': 1,
#  'fac': 2,
#  'happynewyear2020': 1,
#  'Singapore': 41,
#  'Sakura': 1,
#  'httpst': 5,
#  'Memang': 4,
#  'lesen': 1,
#  'motor': 2,
#  'tujercaption': 1,
#  'M': 13,
#  'Muka': 3,
#  'Cristiano': 2,
#  'Kuasa': 1,
#  'Nak': 24,
#  'Melayan': 1,
#  'Dah': 15,
#  'Ta': 6,
#  'ratu': 2,
#  'Masih': 11,
#  'menari': 2,
#  'pegawai': 1,
#  'media': 1,
#  'sos': 1,
#  'depan': 7,
#  'Pergi': 7,
#  'Lagi': 17,
#  'okei': 1,
#  'dataran': 2,
#  'tinggi': 2,
#  'Iya': 3,
#  'Foto': 3,
#  'ini': 32,
#  'hampir': 2,
#  'mirip': 2,
#  'Ma': 12,
#  'sebelumnya': 1,
#  'bed': 1,
#  'Dari': 12,
#  'Banyaknya': 2,
#  'Momen': 3,
#  'Indah': 3,
#  'Banya': 1,
#  'Selalu': 15,
#  'Bahagia': 6,
#  'Kalo': 14,
#  'KEMANA²': 1,
#  'Bisa': 14,
#  'BER3': 1,
#  'N': 9,
#  'Berjimba2': 1,
#  'Sempena': 1,
#  'Abg': 1,
#  'Nazri': 1,
#  'sabtu': 3,
#  'Boleh': 3,
#  'Cengkehanya': 1,
#  'amp': 2,
#  'Kamera': 3,
#  'Triple': 1,
#  'Radenrauf': 1,
#  'Ir': 2,
#  'Soekarno': 1,
#  'Senang': 4,
#  'Saat': 6,
#  'ku': 10,
#  'Kunju': 2,
#  'Menikmati': 5,
#  'Haru': 4,
#  'syukuri': 1,
#  'denga': 3,
#  'Abracadabra': 1,
#  'Bola': 3,
#  'Universalnya': 1,
#  'Gerak': 1,
#  'Sendir': 1,
#  'Jiro': 1,
#  'httpstcopeuanwrkhq': 1,
#  'httpstcozddrbcq47f': 1,
#  'Berkerebalan': 1,
#  'Banyak': 12,
#  'Turis': 1,
#  'untuk': 10,
#  'Berfoto': 1,
#  'Jangan': 15,
#  'Kesibukan': 1,
#  'Itu': 25,
#  'Berhasil': 1,
#  'Menaklukkan': 1,
#  'Fikir': 1,
#  'Permisi': 1,
#  'BENAR': 2,
#  'nya': 9,
#  'selama': 4,
#  'DUDUK': 2,
#  'TUH': 2,
#  'Kaki': 5,
#  'D': 15,
#  'Demi': 1,
#  'apa': 12,
#  'seluruh': 1,
#  'rollercoaster': 2,
#  'Tadi': 5,
#  'Beneran': 4,
#  'Kampret': 1,
#  'Jadi': 16,
#  'Pengen': 2,
#  'Nasi': 5,
#  'Padang': 1,
#  'Bismillah': 2,
#  'Jumat': 1,
#  'Barokah': 2,
#  'Pengujung': 1,
#  'Akhir': 1,
#  'Tahu': 2,
#  'Kok': 8,
#  'Menggemaska': 1,
#  'bersihin': 1,
#  'galeri': 1,
#  'nemu': 2,
#  'wkwkwk': 1,
#  'Panta': 2,
#  'Kembara': 1,
#  'Bersama': 5,
#  'Rakan': 1,
#  'Lama': 5,
#  'Jiwa': 3,
#  'Terasa': 1,
#  'Muda': 1,
#  'Kem': 1,
#  'Tamang': 2,
#  'Tambay': 1,
#  'Kahit': 1,
#  'Walang': 1,
#  'Pera': 3,
#  'berguling': 4,
#  'Red': 1,
#  'Heartred': 1,
#  'Heart': 5,
#  'Kidzania': 2,
#  'htt': 3,
#  'Ubur': 2,
#  'Laut': 6,
#  'Akuarium': 1,
#  'Singapura': 24,
#  'Siapapun': 1,
#  'Mendefinisikan': 1,
#  'Cinta': 3,
#  'Berarti': 1,
#  'Tida': 4,
#  'Naik': 21,
#  'Baru': 9,
#  'terpikir': 1,
#  'Kenapa': 7,
#  'xbawak': 1,
#  'kete': 1,
#  'je': 6,
#  'na': 7,
#  'Sana': 1,
#  'Makaya': 1,
#  'Hahahahahhahaa': 1,
#  'Awakk': 1,
#  'tenung': 2,
#  'apaaa': 1,
#  'tuuu': 1,
#  'Masa': 7,
#  'cherylardih': 1,
#  'ok': 2,
#  'iheh2': 1,
#  'Aja': 13,
#  'Caya': 1,
#  'Sini': 15,
#  'Bawak': 6,
#  'Anak': 6,
#  'Dulu': 16,
#  'Dataang': 1,
#  'Si': 14,
#  'Mikael': 1,
#  'Tengok': 6,
#  'Ikan': 5,
#  'Pulak': 2,
#  'Sea': 2,
#  'Aquarium': 1,
#  'GW': 3,
#  'Suruh': 1,
#  'Cookie': 1,
#  'Monster': 1,
#  'Split': 1,
#  'Dia': 5,
#  'Bisanya': 1,
#  'Begin': 1,
#  'Ride': 7,
#  'Akhirnya': 8,
#  'Setelah': 8,
#  'Sekian': 2,
#  'B': 9,
#  'Mimpi': 7,
#  'Udah': 15,
#  'Tercapai': 2,
#  'Belum': 4,
#  'nih': 5,
#  'asu': 2,
#  'uda': 1,
#  'Memilih': 3,
#  'Tempat': 10,
#  'Wisata': 1,
#  'Cocok': 2,
#  'Untuc': 2,
#  'Semua': 11,
#  'Go': 2,
#  'WAJIB': 2,
#  'httpstco': 8,
#  'Solat': 1,
#  'Jamak': 1,
#  'Masjid': 1,
#  'Vivocity': 8,
#  '新加坡': 1,
#  'httpstcou': 3,
#  'Monung': 1,
#  'httpstcoxe4xubbhef': 1,
#  'Liburan': 16,
#  'disponsori': 1,
#  'ehalesg': 1,
#  'running': 1,
#  'shoe': 1,
#  'Sin': 7,
#  'Kurakura': 4,
#  'Bukan': 14,
#  'Dalam': 18,
#  'Per': 2,
#  'Kuil': 1,
#  'Tiket': 3,
#  'masuk': 9,
#  'USS': 10,
#  'Beli': 6,
#  'Kat': 6,
#  'Klook': 1,
#  'Dapat': 9,
#  'Disk': 1,
#  'Numpang': 3,
#  'doang': 1,
#  'guys': 3,
#  'universalstudios': 1,
#  'Univer': 4,
#  'Setinggi': 2,
#  'Sepanjang': 2,
#  'Banana': 2,
#  'Ni': 16,
#  'Ang': 7,
#  'hirap': 1,
#  'libutin': 1,
#  'ng': 13,
#  'sobrang': 2,
#  'lakas': 1,
#  'uran': 1,
#  'Halo': 2,
#  'Singaporewaving': 1,
#  'Light': 1,
#  'Skin': 3,
#  'Toneyesspa': 1,
#  'Mee': 1,
#  'Pok': 1,
#  'Kesukaan': 1,
#  'Alekssmiling': 1,
#  'Hear': 1,
#  'Hijaukantwitter': 1,
#  'udh': 1,
#  'HIJAU': 1,
#  'HTTPSTCOLLZUNXWJSK': 1,
#  'Kartun': 1,
#  'Faveret': 1,
#  'Kecik2': 1,
#  'dlu': 3,
#  'HttpstComig3rxdyb2': 1,
#  'Rab': 1,
#  'Hsatravelingsingapore': 1,
#  'HSAUniver': 1,
#  'mamimencit': 1,
#  'ciamikboy': 1,
#  'liamgl_': 1,
#  'abcdepiii': 1,
#  'trimurni': 1,
#  'Kamu': 15,
#  'Milih': 1,
#  'Musim': 2,
#  'Panas': 4,
#  'Dingin': 1,
#  'Berdua': 1,
#  'Kaya': 6,
#  'Gini': 3,
#  'Priceless': 1,
#  'Mau': 16,
#  'Bucin': 1,
#  'Gaes': 4,
#  'httpstcokshcj49jj': 1,
#  'BERATUR': 2,
#  'Panjang': 3,
#  'Waktu': 9,
#  'Tunggu': 1,
#  '50Minsunamus': 1,
#  'DUNIA': 5,
#  'Kejam': 1,
#  'Ga': 12,
#  'Berpikiran': 1,
#  'Sama': 11,
#  'Sepert': 1,
#  'Menawarkan': 1,
#  'Pengalaman': 2,
#  'Tersendiri': 1,
#  'Jelas': 2,
#  'Ber': 2,
#  'KDAI': 1,
#  'SEBAB': 2,
#  'WIFI': 2,
#  'tau': 5,
#  'Saya': 22,
#  'Tidak': 15,
#  'berhenti': 1,
#  'percaya': 2,
#  'Pada': 5,
#  'Diri': 3,
#  'Shibuya': 1,
#  'Bread': 1,
#  'Tuk': 2,
#  'Httpstcoqa2ajuarr8': 1,
#  'Btw': 2,
#  'org': 5,
#  'Malaysia': 5,
#  'pun': 6,
#  'ramaei': 1,
#  'Batam': 6,
#  'berseri': 3,
#  'Anda': 6,
#  'Jauh': 5,
#  'Lupa': 8,
#  'Bawa': 2,
#  'Powerbank': 1,
#  'Selepas': 2,
#  'sebulan': 1,
#  'setengah': 1,
#  'take': 1,
#  'lepak': 1,
#  'Daun': 1,
#  'kacang': 1,
#  'Singap': 7,
#  'Im': 62,
#  'shangrilas': 1,
#  'resor': 4,
#  'Siapa': 5,
#  'Penasaran': 1,
#  'Ingin': 4,
#  'Kapal': 7,
#  'P': 6,
#  'sing': 6,
#  'Biasane': 1,
#  'Mung': 2,
#  'Mlebu': 1,
#  'Matahari': 3,
#  'Lan': 2,
#  'Tukune': 1,
#  'Nev': 1,
#  'Masmbak': 1,
#  'mbakfotonya': 1,
#  'nanti': 3,
#  'Kegirangan': 1,
#  'httpstcozybjvo0wqf': 1,
#  'Berausaha': 1,
#  'walau': 2,
#  'tet': 1,
#  'Acaba': 1,
#  'De': 7,
#  'publicar': 1,
#  'una': 1,
#  'en': 2,
#  'Genting': 1,
#  'Catcher': 1,
#  'Two': 2,
#  'Kuta': 2,
#  'Bali': 1,
#  'Indones': 1,
#  'Rainy': 1,
#  'sg': 4,
#  'Dibebaskan': 2,
#  'httpstcobbhml': 1,
#  'Alhamdulillah': 6,
#  'httpstcorccwf2fdzt': 1,
#  'Adik': 3,
#  'punya': 5,
#  'Roller': 1,
#  'Mata': 8,
#  'Mommy': 1,
#  'Semalam': 4,
#  'KetuMu': 7,
#  'Kak': 2,
#  'Lili': 1,
#  'Siregar': 1,
#  'Komisioner': 1,
#  'Kpk': 1,
#  'Moralnya': 1,
#  'jgn': 3,
#  'guring': 1,
#  'time': 1,
#  'cuti2': 1,
#  'lagu': 2,
#  'mmg': 2,
#  'ra': 2,
#  'Singgah': 1,
#  'Cove': 3,
#  'Flag': 2,
#  'S': 20,
#  'Sebagai': 1,
#  'Manusia': 2,
#  'Perikehewana': 1,
#  'AdikkkkKheart': 1,
#  'Suit': 2,
#  'Holiyeayyy': 1,
#  'susah': 2,
#  'cari': 3,
#  'yg': 27,
#  'benerrr': 1,
#  'wkwkwkwbe': 1,
#  'Pertama': 3,
#  'Kali': 7,
#  'Ke': 43,
#  'ferry': 1,
#  'Wefie': 2,
#  'pelabuhan': 1,
#  'xlmediagathering2019': 1,
#  'Lawatan': 1,
#  'Kerja': 5,
#  'sukacita': 2,
#  'st': 1,
#  'Cara': 1,
#  'Senaman': 1,
#  'Ketika': 3,
#  'Perjalanan': 9,
#  'Kalau': 12,
#  'Sewa': 1,
#  'Mobil': 3,
#  'Sekarang': 6,
#  'Pe': 3,
#  'Kresek': 1,
#  'KEMANA2': 1,
#  'APALAGI': 2,
#  'Mendingan': 1,
#  'Nyesel': 1,
#  'Karena': 9,
#  'Mencoba': 3,
#  'Berusia': 2,
#  'Daripad': 1,
#  'DISANA': 1,
#  'DISITU': 1,
#  'DEH': 3,
#  'Instagram': 4,
#  'Wahana': 3,
#  'Mesti': 2,
#  'DiCoba': 1,
#  'Mari': 3,
#  'Piknik': 5,
#  'Instagoo': 1,
#  'Kata': 6,
#  'Mentri': 1,
#  'Acara': 1,
#  'Najwa': 1,
#  'Obagidaa': 1,
#  'Terreeey': 1,
#  'Hoho': 1,
#  'Lohat': 1,
#  'httpstcoeprtco': 1,
#  'Jalan2': 3,
#  'Sakit': 4,
#  'httpstcosbk2acwtuc': 1,
#  'Jarang': 1,
#  'View': 1,
#  'macam': 3,
#  'se': 5,
#  'Twinning': 1,
#  'Jatesahabambuhay': 1,
#  'Sofitel': 1,
#  'Sen': 4,
#  'Sosok': 1,
#  'Akan': 4,
#  'dihormati': 1,
#  'soekar': 1,
#  'Mrt': 3,
#  'Dekat': 4,
#  'Wajiblah': 1,
#  'Ambil': 1,
#  'Gambar': 6,
#  'Kena': 2,
#  'Bag': 2,
#  'Ekstra': 2,
#  'Backpackhand': 1,
#  'Makan': 10,
#  'Siang': 1,
#  'httpstcovrcjx9877c': 1,
#  'Hansem': 2,
#  'Takpe': 1,
#  'Asalkan': 1,
#  'Gaya': 3,
#  'Pusat': 1,
#  'Perhatian': 1,
#  'KEBEBASA': 1,
#  'Maklumlah': 1,
#  'Pantai': 2,
#  'U': 5,
#  'LGT': 1,
#  'Bank': 1,
#  'Dampd': 1,
#  'Amara': 2,
#  'Sanctuary': 1,
#  'GB': 1,
#  'Christmas': 1,
#  'Party': 1,
#  'Bikini': 1,
#  'Bar': 1,
#  'Permen': 1,
#  'Rasananya': 1,
#  'Salam': 1,
#  'Liferecordsmy': 1,
#  'Resmi_aqmal': 1,
#  'Un': 5,
#  'Hari': 18,
#  'berbagi': 1,
#  'gangan': 3,
#  'SARAP': 1,
#  'MAGING': 1,
#  'BATA': 1,
#  'MAN': 2,
#  'SHUGRINGINGRING': 1,
#  'Singa': 10,
#  'Sebagian': 2,
#  'spot': 2,
#  'negeri': 1,
#  'Kamiss': 1,
#  'Sgheart': 1,
#  'httpstcoe0cwc8hfgn': 1,
#  'PENAKUT': 1,
#  'bgt': 5,
#  'ROLER': 1,
#  'COAS': 1,
#  'BERSYUKUR': 3,
#  'SEGALA': 1,
#  'Hal': 3,
#  'Baik': 7,
#  'Kecil': 3,
#  'MAUPUN': 1,
#  'Womens': 1,
#  'Hatbackpack': 1,
#  'kacamata': 2,
#  'getaran': 1,
#  'Babak': 1,
#  'Kedua': 3,
#  'Q': 1,
#  'Jepang': 3,
#  'Yakitori': 2,
#  'Bla': 1,
#  'nayuki': 2,
#  'httpstc': 3,
#  'Sebenernya': 2,
#  'Sukses': 2,
#  'dimanapun': 1,
#  'dahkap': 1,
#  'tampan': 1,
#  'terokss': 1,
#  'Kan': 7,
#  'harini': 1,
#  'Suamiku': 2,
#  'Orang': 14,
#  'Bebas': 1,
#  'mbak': 4,
#  'lihat': 2,
#  'hp': 1,
#  'lamalana': 2,
#  'pusing': 1,
#  'wa': 3,
#  'Editan': 1,
#  'Keren': 2,
#  'Jugaface': 1,
#  'kegembira': 1,
#  'Hidup': 11,
#  'Singaporeflag': 1,
#  'CollisionDronerAceleague': 1,
#  'geng': 2,
#  'fpv': 1,
#  'mengambil': 2,
#  'ali': 1,
#  'Lensa': 1,
#  'Kamia': 2,
#  'Wartawan': 1,
#  'Berita': 1,
#  'Harian': 1,
#  'Bendera': 11,
#  'Singaporeroller': 1,
#  'Coastercarousel': 1,
#  'Hor': 1,
#  'Antrian': 1,
#  'Panjangflexed': 1,
#  'Bicepsflexed': 1,
#  'Biceps': 1,
#  'teh': 2,
#  'BERGODA': 1,
#  'MISTERI': 1,
#  'Alam': 1,
#  'diantar': 1,
#  'kevy': 1,
#  'chevy': 1,
#  'bigblock': 1,
#  '40lt': 1,
#  'COBA': 2,
#  'HTTPSTCOKMBZMRRLYF': 1,
#  'Aida': 1,
#  'Vita': 1,
#  'Pasang': 1,
#  'Meksiko': 1,
#  'Habis': 3,
#  'Cruising': 1,
#  'Butuh': 2,
#  'Energi': 1,
#  'Tambahan': 1,
#  'Mengekang': 1,
#  'Motoin': 2,
#  'BAKalan': 1,
#  '4x': 1,
#  'Jadilah': 2,
#  'Belajar': 3,
#  'Mengembangkangkan': 1,
#  'Diribenchmark': 1,
#  'Klh': 1,
#  'Ahm': 1,
#  'Mejo': 1,
#  'Maalon': 1,
#  'po': 1,
#  'berisi': 1,
#  'contilface': 1,
#  'vomitin': 1,
#  'omdirects_': 1,
#  'bulong': 1,
#  'doong': 1,
#  'weekendngedit': 1,
#  'hawanya': 1,
#  'w': 6,
#  'Mantap': 1,
#  'ya': 21,
#  'Pak': 7,
#  'Thumbs': 1,
#  'Tone': 1,
#  'Universa': 2,
#  'ZIARAH': 1,
#  'JIRAN': 1,
#  'SEBELAH': 1,
#  'Disini': 10,
#  'Cuma': 7,
#  'Strong': 1,
#  'Zero': 1,
#  'KW': 2,
#  'Super': 2,
#  'mumpung': 1,
#  'gaess': 1,
#  'Nagnyelfie': 1,
#  'daddy': 2,
#  'menyeringai': 2,
#  'adalah': 4,
#  'tentang': 1,
#  'bagaimana': 1,
#  'mencap': 1,
#  'Bangkai': 1,
#  'Karam': 1,
#  'Rahat': 1,
#  'Bagi': 1,
#  'Selfie': 5,
#  'Dato': 1,
#  'Khai_salleh': 1,
#  'gala': 1,
#  'premier': 1,
#  'DJ': 1,
#  'Wale': 1,
#  'Babu': 1,
#  'httpstcowr5hw9r44l': 1,
#  'Ajak': 2,
#  'Seneng': 3,
#  'Sempat': 1,
#  'Sampaik': 1,
#  'yuii': 1,
#  'httpstcoej99eUykNA': 1,
#  'Termalu': 1,
#  'Memikirkan': 1,
#  'Keadaan': 1,
#  'Admin': 1,
#  'maaf': 4,
#  'jasa': 1,
#  'titip': 1,
#  'barang': 1,
#  'sedang': 2,
#  'l': 4,
#  'eh': 5,
#  'enak': 3,
#  'Jalan': 12,
#  'Kesini': 10,
#  'kesitu': 1,
#  'Solo': 1,
#  'bepergian': 1,
#  'enaknya': 2,
#  'atu': 1,
#  'Mungkkin': 1,
#  'Esok': 2,
#  'Sel': 2,
#  'diesa': 1,
#  'Pelayara': 1,
#  'cangkir': 1,
#  'jerami': 1,
#  'asin': 1,
#  'karamel': 1,
#  'cokelat': 1,
#  'gula': 1,
#  'Terbang': 1,
#  'Ama': 1,
#  'Mamah': 2,
#  'Papah': 1,
#  'httpstcogy': 1,
#  'Kepada': 1,
#  'sahabatku': 1,
#  'Maulidur': 1,
#  'Rasul': 1,
#  'singapor': 5,
#  'id_oriflame': 1,
#  'Suda': 5,
#  'Ngajakin': 1,
#  'Niek': 1,
#  'Nan': 1,
#  'Wakanda': 1,
#  'poreber': 1,
#  'haha': 2,
#  'iphonexsmax': 1,
#  'Zaman': 1,
#  'monggo': 1,
#  'Pesan': 3,
#  'gtgt': 1,
#  'khutb': 1,
#  'Berasa': 2,
#  'Glowing': 1,
#  'Berjemur': 1,
#  'ht': 4,
#  'Muna': 3,
#  'Bago': 1,
#  'Gibain': 1,
#  'Kalini': 1,
#  'cino': 1,
#  'Face': 12,
#  'Makanan': 4,
#  'sangat': 4,
#  'menakjubkan': 1,
#  'karang': 1,
#  'berani': 1,
#  'bungge': 1,
#  'Sekagum': 1,
#  'Perpustakaan': 2,
#  'Umum': 2,
#  'Gapailah': 1,
#  'Ambisi': 1,
#  'Langit': 2,
#  'Mimpikan': 1,
#  'Jeng': 1,
#  'unkascayaan': 1,
#  'Waktunya': 6,
#  'cape': 1,
#  'HBD': 1,
#  'Syg': 1,
#  'memiliki': 1,
#  'Menyenangkan': 3,
#  'dep': 1,
#  'ALHAMDULILAH': 1,
#  'SELERESI': 1,
#  'Woman': 3,
#  'Marina': 1,
#  'Bay': 1,
#  'Cente': 1,
#  'Dimana': 5,
#  'unkum': 1,
#  'kalinya': 2,
#  'Gue': 5,
#  'mer': 3,
#  'Pilihan': 3,
#  'wajarlah': 1,
#  'mun': 1,
#  'pulah': 1,
#  'pi': 2,
#  'Wis': 2,
#  'kangen': 2,
#  'karo': 1,
#  'mendoan': 1,
#  'httpstcocdofbgvygh': 1,
#  'Keppel': 1,
#  'Phone': 1,
#  'Giant': 1,
#  'Kjwanders': 1,
#  'Seharian': 3,
#  'Puaih': 1,
#  'Ati': 1,
#  'Rumah': 2,
#  'Hantu': 1,
#  'Padiahal': 1,
#  'Suk': 1,
#  'Palawan': 1,
#  'Singapu': 1,
#  'Pagiku': 1,
#  'Cerahku': 1,
#  'Bersinar': 1,
#  'Sun': 3,
#  'Tehanya': 1,
#  'Lumayan': 2,
#  'komentar': 1,
#  'anakana': 1,
#  'warna': 3,
#  'pencahayaan': 1,
#  'Spirit': 1,
#  'Gratis': 2,
#  'Sparkles': 1,
#  'Shangri': 2,
#  'Jalanjalan': 2,
#  'Hujung': 1,
#  'Minggu': 3,
#  'Highland': 2,
#  'Malay': 1,
#  'Marah': 1,
#  'Apabila': 1,
#  'Menghi': 1,
#  'Malam': 17,
#  'Kami': 4,
#  'Sekeluarga': 2,
#  'Menghadiri': 1,
#  'Cewe': 2,
#  'Histeris': 1,
#  'Ngeliatin': 1,
#  'Kayak': 3,
#  'Gin': 1,
#  'Kirain': 1,
#  'Senin': 1,
#  'BAKAL': 1,
#  'TERLALU': 1,
#  'RAME': 2,
#  'KRN': 1,
#  'Jah': 1,
#  'menunggu': 2,
#  'kedatanahan': 1,
#  'keret': 1,
#  'Yuk': 1,
#  'kreta': 1,
#  'transportasi': 1,
#  'transfer': 1,
#  'Walking': 3,
#  'Menencari': 1,
#  'Ketenangan': 1,
#  'Cuti': 2,
#  'pendek': 1,
#  'diwali': 1,
#  'qaisarahzahra': 1,
#  'raishamar': 1,
#  'nakakatakot': 1,
#  'yung': 1,
#  'haba': 1,
#  'pila': 1,
#  'httpstco6swy0': 1,
#  'Blossomblossomblossomblossomblossomblossombloss': 1,
#  'Pasca': 1,
#  'Universitas': 1,
#  'Puzzle': 1,
#  'Piece': 1,
#  'Guildmat': 1,
#  'Bukanlah': 3,
#  'Suatu': 3,
#  'Kesalanan': 1,
#  'da': 4,
#  'tinningtapi': 1,
#  'cuaca': 1,
#  'Mendukung': 1,
#  'hufffll': 1,
#  'Selesai': 1,
#  'Menjarah': 1,
#  'Temasek': 1,
#  'Jemuran': 1,
#  'Kereta': 1,
#  'Gantung': 1,
#  'Pintu': 1,
#  'Gerbang': 1,
#  'Tempt': 1,
#  'Waji': 1,
#  'Tngok': 1,
#  'swatch': 1,
#  'cini': 1,
#  'jap': 1,
#  'vivocitysg': 2,
#  'Ujan': 1,
#  'Jd': 2,
#  'Ngantuk': 1,
#  'Httpstco7ef5w9ymxv': 1,
#  'Game': 1,
#  'Ngumpul': 1,
#  'HANU': 1,
#  'BADUT': 1,
#  'WKWKWKWK': 1,
#  'HTTPSTCOBHB3MREFCV': 1,
#  'Cek': 1,
#  'ngonolo': 1,
#  'rek': 1,
#  'httpstco8b8vvwuluj': 1,
#  'Ambik': 1,
#  'Gambaq': 1,
#  'Ja': 3,
#  'Travel': 1,
#  'fotoin': 1,
#  'Satu': 5,
#  'modelnya': 1,
#  'httpstcod4p': 1,
#  'Lin': 1,
#  'Awak': 4,
#  'Pon': 2,
#  'Cukup': 2,
#  'Lain': 5,
#  'Dtg': 2,
#  'Semata': 1,
#  'Pegi': 1,
#  'Tggu': 1,
#  'Iols': 1,
#  'Lyn': 1,
#  'Sampai': 6,
#  'Muntah': 1,
#  'Layan': 2,
#  'Sunset': 2,
#  'Kt': 1,
#  'Lah': 8,
#  'Plok': 1,
#  'Asyik': 1,
#  'Potret': 1,
#  'Wiwiwiwi': 1,
#  'Ultimat': 1,
#  'Hanya': 7,
#  'sekali': 6,
#  'guyssstetapi': 1,
#  'Jika': 5,
#  'gunak': 1,
#  'biasa': 4,
#  'Oke': 3,
#  'Pekerja': 2,
#  'Seni': 1,
#  'Menyempatkan': 2,
#  'Seben': 1,
#  'Outfit': 1,
#  'Sebelum': 8,
#  'Pulu': 7,
#  'Saksak': 1,
#  ...}

# %% [markdown]
# From the word cloud, we can use the words that are iirelevant to Sentosa and using the code we can replace those words by replacing the text in the brackets below.
#
# - text_col=text_col[~text_col.english_text.str.contains("__vivocity__")]
#
# Replacing the word vivocity with another word that is iirelevant to remove those tweets from our scrapped results shown below.
#
# - text_col=text_col[~text_col.english_text.str.contains("__telok__")]

# %%
text_col=text_col[~text_col.english_text.str.contains("vivocity")]
# removing relevant tweets using the word cloud for reference

# %%
text_col
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username  \
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 leftright arrow Welcome 2020 two hear...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                           susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liatliat peluang mana tahu ada lokasi bis...     Zulkifli_H
# 1052  Big Merlion merlion  sentosaisland  singapore ...  AKKEY52147106
# 1053  sign of the hornscall me hand medium skin tone...     Lex_Kors1n
# 1054  Mimpiku besar  dan aku harap aku bisa mewujudk...        rosiFJP
#
#                                            english_text  \
# 0     Me and my friend but there is a sense of sayin...
# 1     Me and my friends PAUDQ wish you a Happy New Y...
# 2     Me and my friend Genk Motorq wish you a Happy ...
# 3     Thank you for being the closing of my beautifu...
# 4     BYE 2019 ↔ WELCOME 2020 💕 \n . \n Hopefully we...
# ...                                                 ...
# 1050                   @susipudjiastuti greetings ma'am
# 1051  Try to look at the opportunity which knows the...
# 1052  Big Merlion. \n #merlion \n #Sentosaisland \n ...
# 1053  🤘🤙🏽 🇸🇬 #Singapore 01.01.19 PH ZLATESHKA 😉🤙🏽 @ ...
# 1054  My dream is big \n And I hope I can make it ha...
#
#                                                FullText
# 0     AKU dan TEMEN TAPI ADA Rasa Mengucapkan Selama...
# 1     AKU dan TEMEN2 PAUDQ MENGUCAPKAN SELAMAT TAHUN...
# 2     AKU dan TEMEN GENK MOTORQ MENGUCAPKAN SELAMAT ...
# 3     Terimakasih sudah menjadi penutup 2019ku Yang ...
# 4     Bye 2019 Leftright Panah Selamat Datang 2020 T...
# ...                                                 ...
# 1050                          Susi pudjiastuti dalam bi
# 1051  COBA LIATLIAT PELUANG MANA TAHU ADA LOKASI BIS...
# 1052  Big Merlion Merlion Sentosa Island Singapore 場...
# 1053  Tanda Hornscall Me Tangan Medium Kulit Bendera...
# 1054  Mimpiku Besar Dan Aku Harak Aku Bisa Mewujudka...
#
# [1038 rows x 6 columns]

# %% [markdown]
# The next few codes are for preparation for running Sentiment Analysis.

# %%
pretrained_name = "sahri/indonesiasentiment"
# other models can be entered if desired

nlp = pipeline("sentiment-analysis",
              model=pretrained_name,
              tokenizer=pretrained_name)

# %%
def sentiment_analysis_label(FullText):
    '''
    Sentiment analysis labelling
    0 - positive
    1 - negative
    '''
    output = nlp(FullText)
    if output[0]['label'] == 'positive':
        label = str('positive')
    elif output[0]['label'] == 'neutral':
        label = str('neutral')
    else:
        label = str('negative')
    return label

# %%
def sentiment_analysis_score(FullText):
    '''
    Return sentiment analysis score
    '''
    output = nlp(FullText)
    return round(output[0]['score'], 3)

# %%
text_col['sentiment'] = text_col['FullText'].apply(sentiment_analysis_label)
# Out:
# C:\Users\Kelvin\AppData\Local\Temp/ipykernel_12284/379579593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_col['sentiment'] = text_col['FullText'].apply(sentiment_analysis_label)

# %%
text_col['sentiment'].value_counts(ascending=False)
# Out:
# positive    534
# neutral     285
# negative    219
# Name: sentiment, dtype: int64

# %%
text_col['score'] = text_col['FullText'].apply(sentiment_analysis_score)
# Out:
# C:\Users\Kelvin\AppData\Local\Temp/ipykernel_12284/2216666349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_col['score'] = text_col['FullText'].apply(sentiment_analysis_score)

# %%
text_col
# Out:
#                 Datetime             Tweet Id  \
# 0    2019-12-31 17:27:32  1212062746663104514
# 1    2019-12-31 17:21:57  1212061339906191360
# 2    2019-12-31 17:13:57  1212059327609094144
# 3    2019-12-31 17:02:38  1212056479617806337
# 4    2019-12-31 16:40:10  1212050824475615232
# ...                  ...                  ...
# 1050 2019-01-02 08:04:05  1080374154447081473
# 1051 2019-01-01 11:01:24  1080056390855675905
# 1052 2019-01-01 07:31:00  1080003440510554112
# 1053 2019-01-01 06:57:15  1079994946990624770
# 1054 2019-01-01 03:14:31  1079938896291602433
#
#                                                    Text       Username  \
# 0     Aku dan temen tapi ada rasa mengucapkan happy ...       banteths
# 1     Aku dan temen2 paudQ mengucapkan selamat Tahun...       banteths
# 2     Aku dan temen genk motorQ mengucapkan Selamat ...       banteths
# 3     Terimakasih sudah menjadi penutup 2019ku yang ...   noviputrii25
# 4     Bye 2019 leftright arrow Welcome 2020 two hear...  Vinnasaragi13
# ...                                                 ...            ...
# 1050                           susipudjiastuti salam bu   Yudi70117508
# 1051  Coba liatliat peluang mana tahu ada lokasi bis...     Zulkifli_H
# 1052  Big Merlion merlion  sentosaisland  singapore ...  AKKEY52147106
# 1053  sign of the hornscall me hand medium skin tone...     Lex_Kors1n
# 1054  Mimpiku besar  dan aku harap aku bisa mewujudk...        rosiFJP
#
#                                            english_text  \
# 0     Me and my friend but there is a sense of sayin...
# 1     Me and my friends PAUDQ wish you a Happy New Y...
# 2     Me and my friend Genk Motorq wish you a Happy ...
# 3     Thank you for being the closing of my beautifu...
# 4     BYE 2019 ↔ WELCOME 2020 💕 \n . \n Hopefully we...
# ...                                                 ...
# 1050                   @susipudjiastuti greetings ma'am
# 1051  Try to look at the opportunity which knows the...
# 1052  Big Merlion. \n #merlion \n #Sentosaisland \n ...
# 1053  🤘🤙🏽 🇸🇬 #Singapore 01.01.19 PH ZLATESHKA 😉🤙🏽 @ ...
# 1054  My dream is big \n And I hope I can make it ha...
#
#                                                FullText sentiment  score
# 0     AKU dan TEMEN TAPI ADA Rasa Mengucapkan Selama...  positive  0.971
# 1     AKU dan TEMEN2 PAUDQ MENGUCAPKAN SELAMAT TAHUN...  positive  0.984
# 2     AKU dan TEMEN GENK MOTORQ MENGUCAPKAN SELAMAT ...  positive  0.965
# 3     Terimakasih sudah menjadi penutup 2019ku Yang ...  positive  0.854
# 4     Bye 2019 Leftright Panah Selamat Datang 2020 T...   neutral  0.687
# ...                                                 ...       ...    ...
# 1050                          Susi pudjiastuti dalam bi   neutral  0.999
# 1051  COBA LIATLIAT PELUANG MANA TAHU ADA LOKASI BIS...  positive  0.991
# 1052  Big Merlion Merlion Sentosa Island Singapore 場...  positive  0.947
# 1053  Tanda Hornscall Me Tangan Medium Kulit Bendera...  positive  0.992
# 1054  Mimpiku Besar Dan Aku Harak Aku Bisa Mewujudka...  positive  0.995
#
# [1038 rows x 8 columns]

# %% [markdown]
# This code is used to save your results.

# %%
text_col.to_excel('geo location 2019 tweets wo emoji translated senti.xlsx', sheet_name='sheet1', index=False)
# saving results to excel as emojis are unable to be saved in csv form
tweetid= text_col['Tweet Id']
tweetid.to_csv('tweetsID.csv', index=False)
# due to the tweet ID being too long. it has be to saved separately

# %% [markdown]
# Run the code below and change the "__geo location 2019 tweets wo emoji translated senti.xlsx__" to the excel file name you want to load.

# %%
# please enter the relevant filename 
text_col=pd.read_excel('geo location 2019 tweets wo emoji translated senti.xlsx')  

text_col

# %% [markdown]
# With the final results. We are using ploty to show what kind of sentiment is applicable for the period we have defined earlier.

# %%
fig=px.histogram(text_col, x="Datetime",color="sentiment")
fig.show()
