# %%
import pandas as pd

# %%
df = pd.read_excel("master_copy.xlsx")
df.head()
# Out:
#           user                 date                rating  \
# 0    mpocasino  2020-08-01 00:00:00  5,0 dari 5 lingkaran
# 1       Rudy K  2019-11-01 00:00:00  5,0 dari 5 lingkaran
# 2    Alma Jaya  2019-08-01 00:00:00  5,0 dari 5 lingkaran
# 3  Sri Pratiwi  2020-02-01 00:00:00  5,0 dari 5 lingkaran
# 4      Didik K  2020-02-01 00:00:00  5,0 dari 5 lingkaran
#
#                                               review  \
# 0  Universal Studio Singapore yang berada di Pula...
# 1  cukup beruntung hanya membeli tiket biasa dapa...
# 2  Tempat liburan keluarga yang sangat menarik un...
# 3  Beli tiketnya via OTA dan kebetulan sudah prin...
# 4  Jalan jalan bareng si kecil, emang menyenangka...
#
#                                             page_url date_scraped  \
# 0  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 1  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 2  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 3  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 4  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
#
#         source attraction
# 0  tripadvisor        uss
# 1  tripadvisor        uss
# 2  tripadvisor        uss
# 3  tripadvisor        uss
# 4  tripadvisor        uss

# %%
import datetime
from dateutil.relativedelta import relativedelta

# %%
def fix_date_week(week):
  date = datetime.datetime.now()
  date = date.date()
  newdate = date - relativedelta(weeks=week)
  return newdate

# %%
def fix_date_month(month):
  date = datetime.datetime.now()
  date = date.date()
  newdate = date - relativedelta(months=month)
  return newdate

# %%
def fix_date_year(year):
  date = datetime.datetime.now()
  date = date.date()
  newdate = date - relativedelta(years=year)
  return newdate

# %%
# Replace date strings with proper year
# Only up to 10 years
replace_date = {'seminggu lalu': fix_date_week(1),
                '2 minggu lalu': fix_date_week(2),
                '3 minggu lalu': fix_date_week(3),
                'sebulan lalu': fix_date_month(1),
                '2 bulan lalu': fix_date_month(2),
                '3 bulan lalu': fix_date_month(3),
                '4 bulan lalu': fix_date_month(4),
                '5 bulan lalu': fix_date_month(5),
                '6 bulan lalu': fix_date_month(6),
                '7 bulan lalu': fix_date_month(7),
                '8 bulan lalu': fix_date_month(8),
                '9 bulan lalu': fix_date_month(9),
                '10 bulan lalu': fix_date_month(10),
                '11 bulan lalu': fix_date_month(11),
                'setahun lalu': fix_date_year(1),
                '2 tahun lalu': fix_date_year(2),
                '3 tahun lalu': fix_date_year(3),
                '4 tahun lalu': fix_date_year(4),
                '5 tahun lalu': fix_date_year(5),
                '6 tahun lalu': fix_date_year(6),
                '7 tahun lalu': fix_date_year(7),
                '8 tahun lalu': fix_date_year(8),
                '9 tahun lalu': fix_date_year(9),
                '10 tahun lalu': fix_date_year(10),}

# %%
# Split dataframe with proper datetime format
df1 = df[df['date'].apply(lambda x: isinstance(x, datetime.date))]
df1.head()
# Out:
#           user                 date                rating  \
# 0    mpocasino  2020-08-01 00:00:00  5,0 dari 5 lingkaran
# 1       Rudy K  2019-11-01 00:00:00  5,0 dari 5 lingkaran
# 2    Alma Jaya  2019-08-01 00:00:00  5,0 dari 5 lingkaran
# 3  Sri Pratiwi  2020-02-01 00:00:00  5,0 dari 5 lingkaran
# 4      Didik K  2020-02-01 00:00:00  5,0 dari 5 lingkaran
#
#                                               review  \
# 0  Universal Studio Singapore yang berada di Pula...
# 1  cukup beruntung hanya membeli tiket biasa dapa...
# 2  Tempat liburan keluarga yang sangat menarik un...
# 3  Beli tiketnya via OTA dan kebetulan sudah prin...
# 4  Jalan jalan bareng si kecil, emang menyenangka...
#
#                                             page_url date_scraped  \
# 0  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 1  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 2  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 3  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 4  https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
#
#         source attraction
# 0  tripadvisor        uss
# 1  tripadvisor        uss
# 2  tripadvisor        uss
# 3  tripadvisor        uss
# 4  tripadvisor        uss

# %%
# Split dataframe with date strings
df2 = df[df['date'].apply(lambda x: not isinstance(x, datetime.date))]
df2.head()
# Out:
#                            user           date                     rating  \
# 1659           desuka Panjaitan  10 bulan lalu  Diberi rating 5,0 dari 5,
# 1660      Riska Septi Damayanti   8 bulan lalu  Diberi rating 5,0 dari 5,
# 1661  Mochamad Naufal Irfansyah   6 bulan lalu  Diberi rating 5,0 dari 5,
# 1662                      T1y25   5 bulan lalu  Diberi rating 5,0 dari 5,
# 1663         Ichsanarias Rindes   setahun lalu  Diberi rating 5,0 dari 5,
#
#                                                  review  \
# 1659  Belum Pernah Masuk kedalam, hanya diluar saja....
# 1660  Sumpahh kalo ke Singapore wajib banget ke sini...
# 1661  Seru bisa jajan coklat enak dan murah, kalo ma...
# 1662   Luas banget,banyak spot fotonya,wahananya keren²
# 1663  Tempat yang gak akan gagal membuat semua orang...
#
#                                                page_url date_scraped  \
# 1659  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1660  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1661  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1662  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1663  https://www.google.com/search?q=universal+stud...    4/27/2022
#
#               source attraction
# 1659  google_reviews        uss
# 1660  google_reviews        uss
# 1661  google_reviews        uss
# 1662  google_reviews        uss
# 1663  google_reviews        uss

# %%
df2 = df2.replace({"date": replace_date})

# %%
df2
# Out:
#                            user        date                     rating  \
# 1659           desuka Panjaitan  2021-07-11  Diberi rating 5,0 dari 5,
# 1660      Riska Septi Damayanti  2021-09-11  Diberi rating 5,0 dari 5,
# 1661  Mochamad Naufal Irfansyah  2021-11-11  Diberi rating 5,0 dari 5,
# 1662                      T1y25  2021-12-11  Diberi rating 5,0 dari 5,
# 1663         Ichsanarias Rindes  2021-05-11  Diberi rating 5,0 dari 5,
# ...                         ...         ...                        ...
# 3154                  Ira Wanti  2020-05-11  Diberi rating 5,0 dari 5,
# 3155               budi santoso  2020-05-11  Diberi rating 5,0 dari 5,
# 3156            Sulastri Rahayu  2016-05-11  Diberi rating 4,0 dari 5,
# 3157           Herry Sudarwanto  2019-05-11  Diberi rating 5,0 dari 5,
# 3158                    Dewi mw  2019-05-11  Diberi rating 5,0 dari 5,
#
#                                                  review  \
# 1659  Belum Pernah Masuk kedalam, hanya diluar saja....
# 1660  Sumpahh kalo ke Singapore wajib banget ke sini...
# 1661  Seru bisa jajan coklat enak dan murah, kalo ma...
# 1662   Luas banget,banyak spot fotonya,wahananya keren²
# 1663  Tempat yang gak akan gagal membuat semua orang...
# ...                                                 ...
# 3154                            Sukses selalu Singapura
# 3155                                     Tempat e asyik
# 3156              Keren bgt...♥Q sdh pernh dtng ke sana
# 3157                                              Bagus
# 3158                                      Seneng banget
#
#                                                page_url date_scraped  \
# 1659  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1660  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1661  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1662  https://www.google.com/search?q=universal+stud...    4/27/2022
# 1663  https://www.google.com/search?q=universal+stud...    4/27/2022
# ...                                                 ...          ...
# 3154  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3155  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3156  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3157  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3158  https://www.google.com/search?q=universal+stud...    4/27/2022
#
#               source attraction
# 1659  google_reviews        uss
# 1660  google_reviews        uss
# 1661  google_reviews        uss
# 1662  google_reviews        uss
# 1663  google_reviews        uss
# ...              ...        ...
# 3154  google_reviews        uss
# 3155  google_reviews        uss
# 3156  google_reviews        uss
# 3157  google_reviews        uss
# 3158  google_reviews        uss
#
# [1500 rows x 8 columns]

# %%
# Only extract year
df1['date'] = pd.DatetimeIndex(df1['date']).year
df2['date'] = pd.DatetimeIndex(df2['date']).year
# Out:
# C:\Users\Luqman\AppData\Local\Temp/ipykernel_16656/1858279160.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['date'] = pd.DatetimeIndex(df1['date']).year

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df
# Out:
#                   user  date                     rating  \
# 0            mpocasino  2020       5,0 dari 5 lingkaran
# 1               Rudy K  2019       5,0 dari 5 lingkaran
# 2            Alma Jaya  2019       5,0 dari 5 lingkaran
# 3          Sri Pratiwi  2020       5,0 dari 5 lingkaran
# 4              Didik K  2020       5,0 dari 5 lingkaran
# ...                ...   ...                        ...
# 3154         Ira Wanti  2020  Diberi rating 5,0 dari 5,
# 3155      budi santoso  2020  Diberi rating 5,0 dari 5,
# 3156   Sulastri Rahayu  2016  Diberi rating 4,0 dari 5,
# 3157  Herry Sudarwanto  2019  Diberi rating 5,0 dari 5,
# 3158           Dewi mw  2019  Diberi rating 5,0 dari 5,
#
#                                                  review  \
# 0     Universal Studio Singapore yang berada di Pula...
# 1     cukup beruntung hanya membeli tiket biasa dapa...
# 2     Tempat liburan keluarga yang sangat menarik un...
# 3     Beli tiketnya via OTA dan kebetulan sudah prin...
# 4     Jalan jalan bareng si kecil, emang menyenangka...
# ...                                                 ...
# 3154                            Sukses selalu Singapura
# 3155                                     Tempat e asyik
# 3156              Keren bgt...♥Q sdh pernh dtng ke sana
# 3157                                              Bagus
# 3158                                      Seneng banget
#
#                                                page_url date_scraped  \
# 0     https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 1     https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 2     https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 3     https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# 4     https://www.tripadvisor.co.id/Attraction_Revie...    4/26/2022
# ...                                                 ...          ...
# 3154  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3155  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3156  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3157  https://www.google.com/search?q=universal+stud...    4/27/2022
# 3158  https://www.google.com/search?q=universal+stud...    4/27/2022
#
#               source attraction
# 0        tripadvisor        uss
# 1        tripadvisor        uss
# 2        tripadvisor        uss
# 3        tripadvisor        uss
# 4        tripadvisor        uss
# ...              ...        ...
# 3154  google_reviews        uss
# 3155  google_reviews        uss
# 3156  google_reviews        uss
# 3157  google_reviews        uss
# 3158  google_reviews        uss
#
# [3159 rows x 8 columns]

# %%
df.to_excel("reviews_normalized_year.xlsx", index=False)
