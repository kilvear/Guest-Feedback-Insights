# %%
import pandas as pd

# %%
df = pd.read_excel('reviews_normalized_rating.xlsx')

# %%
df
# Out:
#                   user  date  rating  \
# 0            mpocasino  2020      10
# 1               Rudy K  2019      10
# 2            Alma Jaya  2019      10
# 3          Sri Pratiwi  2020      10
# 4              Didik K  2020      10
# ...                ...   ...     ...
# 3154         Ira Wanti  2020      10
# 3155      budi santoso  2020      10
# 3156   Sulastri Rahayu  2016       8
# 3157  Herry Sudarwanto  2019      10
# 3158           Dewi mw  2019      10
#
#                                                  review  \
# 0     Universal Studio Singapore yang berada di Pula...
# 1     cukup beruntung hanya membeli tiket biasa dapa...
# 2     Tempat liburan keluarga yang sangat menarik un...
# 3     Beli tiketnya via OTA dan kebetulan sudah prin...
# 4     Jalan jalan bareng si kecil, emang menyenangka...
# ...                                                 ...
# 3154                            Sukses selalu Singapura
# 3155                                     Tempat e asyik
# ...

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
#                        user  date  rating  \
# 138         mohamad termizi  2020      10
# 139         mohamad termizi  2020      10
# 140         mohamad termizi  2020      10
# 146                ayu putu  2020      10
# 152          valerie angela  2020       8
# 154  Muhammad Rahman Fajrin  2020      10
# 155  Muhammad Rahman Fajrin  2020      10
# 157  Muhammad Rahman Fajrin  2020      10
# 158  Muhammad Rahman Fajrin  2020      10
# 165                  steven  2020      10
# 166                  steven  2020      10
# 167                  steven  2020      10
# 168                  steven  2020      10
# 169                  steven  2020      10
# 173                    Nova  2020      10
# 174                    Nova  2020      10
# 193             Ageng hanif  2020      10
# 196          Graha Iman Adi  2020      10
# 197          Graha Iman Adi  2020      10
# 201             Ageng hanif  2020      10
# 209                     edi  2020      10
# ...

# %%
# Remove duplicate rows
df.drop_duplicates(keep='first', inplace=True)

# %%
df
# Out:
#                   user  date  rating  \
# 0            mpocasino  2020      10
# 1               Rudy K  2019      10
# 2            Alma Jaya  2019      10
# 3          Sri Pratiwi  2020      10
# 4              Didik K  2020      10
# ...                ...   ...     ...
# 3154         Ira Wanti  2020      10
# 3155      budi santoso  2020      10
# 3156   Sulastri Rahayu  2016       8
# 3157  Herry Sudarwanto  2019      10
# 3158           Dewi mw  2019      10
#
#                                                  review  \
# 0     Universal Studio Singapore yang berada di Pula...
# 1     cukup beruntung hanya membeli tiket biasa dapa...
# 2     Tempat liburan keluarga yang sangat menarik un...
# 3     Beli tiketnya via OTA dan kebetulan sudah prin...
# 4     Jalan jalan bareng si kecil, emang menyenangka...
# ...                                                 ...
# 3154                            Sukses selalu Singapura
# 3155                                     Tempat e asyik
# ...

# %%
df.to_excel('reviews_removed_duplicates.xlsx', index=False)
